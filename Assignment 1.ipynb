# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %%
olympic = pd.read_csv('C:\\Users\\rashi\\OneDrive\\Desktop\\Asmt1\\olympics_medals_country_wise.csv')

# %%
olympic.head()
# Out:
#     countries  ioc_code   summer_participations summer_gold  summer_silver  \
# 0  Afghanistan     (AFG)                     15           0              0
# 1      Algeria     (ALG)                     14           5              4
# 2    Argentina     (ARG)                     25          21             26
# 3      Armenia     (ARM)                      7           2              8
# 4  Australasia     (ANZ)                      2           3              4
#
#    summer_bronze summer_total  winter_participations  winter_gold  \
# 0              2            2                      0            0
# 1              8           17                      3            0
# 2             30           77                     20            0
# 3              8           18                      8            0
# 4              5           12                      0            0
#
#    winter_silver  winter_bronze  winter_total  total_participation total_gold  \
# ...

# %%
olympic.tail()
# Out:
#                             countries  ioc_code   summer_participations  \
# 151                             Zambia     (ZAM)                     14
# 152                           Zimbabwe     (ZIM)                     14
# 153       Independent Olympic Athletes     (IOA)                      3
# 154  Independent Olympic Participants      (IOP)                      1
# 155                        Mixed Team      (ZZX)                      3
#
#     summer_gold  summer_silver  summer_bronze summer_total  \
# 151           0              1              1            2
# 152           3              4              1            8
# 153           1              0              1            2
# 154           0              1              2            3
# 155          11              6              8           25
#
#      winter_participations  winter_gold  winter_silver  winter_bronze  \
# 151                      0            0              0              0
# ...

# %%
olympic.describe()
# Out:
#        summer_participations  summer_silver  summer_bronze  \
# count             156.000000     156.000000     156.000000
# mean               14.673077      34.782051      37.775641
# std                 7.432417      86.085726      83.157105
# min                 0.000000       0.000000       0.000000
# 25%                 9.750000       1.000000       1.000000
# 50%                15.000000       5.000000       6.000000
# 75%                19.000000      29.250000      31.250000
# max                29.000000     831.000000     738.000000
#
#        winter_participations  winter_gold  winter_silver  winter_bronze  \
# count             156.000000    156.00000     156.000000     156.000000
# mean                7.314103      7.50641       7.487179       7.442308
# std                 7.900024     22.23264      21.431808      20.126773
# min                 0.000000      0.00000       0.000000       0.000000
# ...

# %%
olympic.isna().any()
# Out:
# countries                False
# ioc_code                 False
# summer_participations    False
# summer_gold              False
# summer_silver            False
# summer_bronze            False
# summer_total             False
# winter_participations    False
# winter_gold              False
# winter_silver            False
# winter_bronze            False
# winter_total             False
# total_participation      False
# total_gold               False
# total_silver             False
# total_bronze             False
# total_total              False
# dtype: bool

# %%
olympic.isna().sum()
# Out:
# countries                0
# ioc_code                 0
# summer_participations    0
# summer_gold              0
# summer_silver            0
# summer_bronze            0
# summer_total             0
# winter_participations    0
# winter_gold              0
# winter_silver            0
# winter_bronze            0
# winter_total             0
# total_participation      0
# total_gold               0
# total_silver             0
# total_bronze             0
# total_total              0
# dtype: int64

# %%
olympic[olympic.total_participation.isna()==True]
# Out:
# Empty DataFrame
# Columns: [countries , ioc_code , summer_participations, summer_gold, summer_silver, summer_bronze, summer_total, winter_participations, winter_gold, winter_silver, winter_bronze, winter_total, total_participation, total_gold, total_silver, total_bronze, total_total ]
# Index: []

# %%
olympic.total_participation.value_counts()
# Out:
# 15    16
# 14     7
# 23     7
# 11     7
# 13     7
# 10     7
# 18     7
# 16     7
# 17     6
# 22     5
# 52     4
# 27     4
# 3      4
# 53     3
# 51     3
# 30     3
# 8      3
# 19     3
# 24     3
# 1      3
# 49     3
# 45     3
# 2      3
# 7      2
# 36     2
# 12     2
# 28     2
# 41     2
# 34     2
# 20     2
# 42     2
# 29     2
# 6      2
# 32     2
# 9      2
# 21     2
# 40     1
# 25     1
# 47     1
# 4      1
# 37     1
# 38     1
# 50     1
# 35     1
# 43     1
# 46     1
# 44     1
# 26     1
# Name: total_participation, dtype: int64

# %%
olympic.duplicated().any()
# Out:
# False

# %%
olympic.isna().sum()
# Out:
# countries                0
# ioc_code                 0
# summer_participations    0
# summer_gold              0
# summer_silver            0
# summer_bronze            0
# summer_total             0
# winter_participations    0
# winter_gold              0
# winter_silver            0
# winter_bronze            0
# winter_total             0
# total_participation      0
# total_gold               0
# total_silver             0
# total_bronze             0
# total_total              0
# dtype: int64

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   countries              156 non-null    object
#  1   ioc_code               156 non-null    object
#  2   summer_participations  156 non-null    int64
#  3   summer_gold            156 non-null    object
#  4   summer_silver          156 non-null    int64
#  5   summer_bronze          156 non-null    int64
#  6   summer_total           156 non-null    object
#  7   winter_participations  156 non-null    int64
#  8   winter_gold            156 non-null    int64
#  9   winter_silver          156 non-null    int64
#  10  winter_bronze          156 non-null    int64
#  11  winter_total           156 non-null    int64
#  12  total_participation    156 non-null    int64
#  13  total_gold             156 non-null    object
#  14  total_silver           156 non-null    int64
# ...

# %%
olympic[olympic.summer_silver == 0].head()
# Out:
#              countries  ioc_code   summer_participations summer_gold  \
# 0           Afghanistan     (AFG)                     15           0
# 10             Barbados     (BAR)                     13           0
# 13              Bermuda     (BER)                     19           1
# 17  British West Indies     (BWI)                      1           0
# 19         Burkina Faso     (BUR)                     10           0
#
#     summer_silver  summer_bronze summer_total  winter_participations  \
# 0               0              2            2                      0
# 10              0              1            1                      0
# 13              0              1            2                      8
# 17              0              2            2                      0
# 19              0              1            1                      0
#
#     winter_gold  winter_silver  winter_bronze  winter_total  \
# 0             0              0              0             0
# ...

# %%
olympic['summer_participations'].unique()
# Out:
# array([15, 14, 25,  7,  2, 27, 28, 17, 10, 13, 19,  3, 11, 23,  1, 21, 24,
#        20, 16,  8,  9,  6, 26, 29,  5, 18, 22, 12,  4,  0], dtype=int64)

# %%
olympics = olympic.iloc[:, :11]
olympics
# Out:
#                             countries  ioc_code   summer_participations  \
# 0                          Afghanistan     (AFG)                     15
# 1                              Algeria     (ALG)                     14
# 2                            Argentina     (ARG)                     25
# 3                              Armenia     (ARM)                      7
# 4                          Australasia     (ANZ)                      2
# ..                                 ...       ...                    ...
# 151                             Zambia     (ZAM)                     14
# 152                           Zimbabwe     (ZIM)                     14
# 153       Independent Olympic Athletes     (IOA)                      3
# 154  Independent Olympic Participants      (IOP)                      1
# 155                        Mixed Team      (ZZX)                      3
#
#     summer_gold  summer_silver  summer_bronze summer_total  \
# ...

# %%
most_medals = olympics.nlargest(5,'winter_bronze')
most_medals
# Out:
#         countries  ioc_code   summer_participations summer_gold  \
# 97          Norway     (NOR)                     27          62
# 144  United States     (USA)                     28       1,060
# 6          Austria     (AUT)                     28          20
# 22          Canada     (CAN)                     27          71
# 42         Finland     (FIN)                     26         101
#
#      summer_silver  summer_bronze summer_total  winter_participations  \
# 97              51             50          163                     24
# 144            831            738        2,629                     24
# 6               35             41           96                     24
# 22             109            146          326                     24
# 42              85            119          305                     24
#
#      winter_gold  winter_silver  winter_bronze
# 97           148            133            124
# 144          113            122             95
# ...

# %%
sns.set_style('darkgrid')
plt.hist(most_medals['summer_total'])
plt.xlabel('Top 5 summer medalist')
plt.ylabel('Count')
plt.margins(0.10)
plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.scatter(olympics["summer_bronze"], olympics["winter_bronze"], color="g")
plt.xlabel("summer_bronze", fontsize=14)
plt.ylabel("winter_bronze", fontsize=14)
plt.title("summer_bronze Vs winter_bronze", fontsize=14)

plt.show()
